# %% [markdown]
# # 📊 Wealth Inequality and Living Standards in Europe
#
# ## 🧠 Project Overview
#
# This data science project explores the relationship between **wealth inequality** and **living standards** across European countries. Using publicly available datasets, we investigate whether rising inequality correlates with declining or stagnating quality of life indicators such as poverty rates, income levels, and material deprivation.
#
# ---
#
# ## 🎯 Objectives
#
# - Analyze **trends in income inequality** across European countries (Gini coefficient, top income shares).
# - Measure **living standards** using indicators like poverty rates, median income, and AROPE.
# - Explore statistical **correlation** or patterns between inequality and living standards.
# - Compare **country-level** performance and identify high-risk or resilient societies.
#
# ---
#
# ## 📂 Data Sources
#
# - **Eurostat**
#   - Gini coefficient, AROPE, median income
#   - [https://ec.europa.eu/eurostat](https://ec.europa.eu/eurostat)
#
# - **OECD Income and Wealth Distribution Database**
#   - [https://www.oecd.org/social/income-distribution-database.htm](https://www.oecd.org/social/income-distribution-database.htm)
#
# - **World Inequality Database (WID.world)**
#   - Top 1% income/wealth shares
#   - [https://wid.world](https://wid.world)
#
# - **Our World in Data / Gapminder (for visual storytelling)**
#   - [https://ourworldindata.org](https://ourworldindata.org)
#   - [https://www.gapminder.org](https://www.gapminder.org)
#
#   ## 📈 Key Questions
#
# - How has income/wealth inequality changed over time in Europe?
# - Are countries with higher inequality experiencing worse living standards?
# - Which indicators show the strongest connection to inequality (e.g., poverty rate vs. homeownership)?
# - Are there countries that defy the trend?

# %%
#imports
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
gini_coefficients = pd.read_csv(f'../data/estat_tessi190_en.csv')
poverty = pd.read_csv(f'../data/estat_sdg_01_10_en.csv')

# %%
poverty[poverty['Geopolitical entity (reporting)'] == "Czechia"].head()
# Out:
#    STRUCTURE          STRUCTURE_ID  \
# 49  dataflow  ESTAT:SDG_01_10(1.0)
# 50  dataflow  ESTAT:SDG_01_10(1.0)
# 51  dataflow  ESTAT:SDG_01_10(1.0)
# 52  dataflow  ESTAT:SDG_01_10(1.0)
# 53  dataflow  ESTAT:SDG_01_10(1.0)
#
#                                     STRUCTURE_NAME freq Time frequency    age  \
# 49  Persons at risk of poverty or social exclusion    A         Annual  TOTAL
# 50  Persons at risk of poverty or social exclusion    A         Annual  TOTAL
# 51  Persons at risk of poverty or social exclusion    A         Annual  TOTAL
# 52  Persons at risk of poverty or social exclusion    A         Annual  TOTAL
# 53  Persons at risk of poverty or social exclusion    A         Annual  TOTAL
#
#    Age class unit Unit of measure geo Geopolitical entity (reporting)  \
# 49     Total   PC      Percentage  CZ                         Czechia
# 50     Total   PC      Percentage  CZ                         Czechia
# ...

# %%
# Example: Gini over time by country
plt.figure(figsize=(12,6))
sns.lineplot(data=gini_coefficients[gini_coefficients['Geopolitical entity (reporting)'] == "Czechia"], x='TIME_PERIOD', y='OBS_VALUE', hue='Geopolitical entity (reporting)')
plt.title('Gini Coefficient Over Time')
plt.ylabel('Gini Coefficient')
plt.show()

# %%
# Example: Gini over time by country
plt.figure(figsize=(12,6))
sns.lineplot(data=poverty[poverty['Geopolitical entity (reporting)'] == "Czechia"], x='TIME_PERIOD', y='OBS_VALUE', hue='Geopolitical entity (reporting)')
plt.title('Gini Coefficient Over Time')
plt.ylabel('Gini Coefficient')
plt.show()
